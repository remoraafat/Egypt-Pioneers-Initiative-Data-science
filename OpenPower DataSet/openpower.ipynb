# %%
import pandas as pd

df = pd.read_csv("openpowerlifting.csv")

# %%
df.head(10)
# Out:
#    MeetID                    Name Sex   Equipment   Age     Division  \
# 0       0        Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1       0             Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2       0             Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3       0             Dawn Bogart   F         Raw  42.0  Open Senior
# 4       0            Destiny Dula   F         Raw  18.0   Teen 18-19
# 5       0         Courtney Norris   F       Wraps  28.0  Open Senior
# 6       0           Maureen Clary   F         Raw  60.0    Mst 60-64
# 7       0           Maureen Clary   F         Raw  60.0  Open Senior
# 8       0  Priscilla Sweat Pardue   F       Wraps  52.0        50-54
# 9       0  Priscilla Sweat Pardue   F         Raw  52.0       Senior
#
#    BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  \
# 0         59.60            60       NaN        47.63       NaN        20.41
# ...

# %%
df.sample(10)
# Out:
#         MeetID                  Name Sex   Equipment   Age      Division  \
# 73200     1573        Conrad Claunch   M         Raw   NaN         youth
# 381896    8444        Sergey Simakov   M       Wraps  31.0  Amateur Open
# 216065    6204        Taten Guillory   M  Single-ply   NaN          Boys
# 85055     2087  Arne Birger Birkedal   M  Single-ply   NaN          Open
# 286850    7129      Zachary Haughney   M         Raw   NaN           R-O
# 342256    7856         Christian Lee   M         Raw  32.0          Open
# 7099       103        William Mosher   M         Raw  58.0   M_MR_4_AWPC
# 38409     1120        Avi Silverberg   M         Raw   NaN          Open
# 380859    8432       Michael Gregory   M         Raw  25.0          Open
# 276880    7023        Destiny Turner   F  Single-ply   NaN             C
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 73200          28.49            44       NaN          NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386414 entries, 0 to 386413
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MeetID          386414 non-null  int64
#  1   Name            386414 non-null  object
#  2   Sex             386414 non-null  object
#  3   Equipment       386414 non-null  object
#  4   Age             147147 non-null  float64
#  5   Division        370571 non-null  object
#  6   BodyweightKg    384012 non-null  float64
#  7   WeightClassKg   382602 non-null  object
#  8   Squat4Kg        1243 non-null    float64
#  9   BestSquatKg     298071 non-null  float64
#  10  Bench4Kg        1962 non-null    float64
#  11  BestBenchKg     356364 non-null  float64
#  12  Deadlift4Kg     2800 non-null    float64
#  13  BestDeadliftKg  317847 non-null  float64
#  14  TotalKg         363237 non-null  float64
#  15  Place           385322 non-null  object
# ...

# %%
df.describe(include="int64")
# Out:
#               MeetID
# count  386414.000000
# mean     5143.015804
# std      2552.099838
# min         0.000000
# 25%      2979.000000
# 50%      5960.000000
# 75%      7175.000000
# max      8481.000000

# %%
df.describe(include="object")
# Out:
#                   Name     Sex Equipment Division WeightClassKg   Place
# count           386414  386414    386414   370571        382602  385322
# unique          136687       2         5     4246            51      81
# top     Sverre Paulsen       M       Raw     Open            90       1
# freq               183  299045    186317    68618         35981  194693

# %%
df.describe(include="float64")
# Out:
#                  Age   BodyweightKg     Squat4Kg    BestSquatKg     Bench4Kg  \
# count  147147.000000  384012.000000  1243.000000  298071.000000  1962.000000
# mean       31.668237      86.934912   107.036404     176.569941    45.722905
# std        12.900342      23.140843   166.976620      69.222785   151.668221
# min         5.000000      15.880000  -440.500000    -477.500000  -360.000000
# 25%        22.000000      70.300000    87.500000     127.500000   -90.000000
# 50%        28.000000      83.200000   145.000000     174.630000    90.250000
# 75%        39.000000     100.000000   212.500000     217.720000   167.500000
# max        95.000000     242.400000   450.000000     573.790000   378.750000
#
#          BestBenchKg  Deadlift4Kg  BestDeadliftKg        TotalKg  \
# count  356364.000000  2800.000000   317847.000000  363237.000000
# mean      118.347509   113.597193      195.040633     424.000249
# std        54.848850   170.201657       61.580675     196.355147
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# MeetID                 0
# Name                   0
# Sex                    0
# Equipment              0
# Age               238841
# Division           15843
# BodyweightKg        2399
# WeightClassKg       3807
# Squat4Kg          384626
# BestSquatKg        87964
# Bench4Kg          383918
# BestBenchKg        29944
# Deadlift4Kg       383081
# BestDeadliftKg     68422
# TotalKg            23072
# Place               1092
# Wilks              24115
# dtype: int64

# %%
df.count()
# Out:
# MeetID            385869
# Name              385869
# Sex               385869
# Equipment         385869
# Age               147028
# Division          370026
# BodyweightKg      383470
# WeightClassKg     382062
# Squat4Kg            1243
# BestSquatKg       297905
# Bench4Kg            1951
# BestBenchKg       355925
# Deadlift4Kg         2788
# BestDeadliftKg    317447
# TotalKg           362797
# Place             384777
# Wilks             361754
# dtype: int64

# %%
df.drop(["Age" , "Squat4Kg" , "Bench4Kg" ,"Deadlift4Kg" ] , axis=1 , inplace=True)

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i].fillna(df[i].mode()[0] , inplace=True) 
    elif df[i].dtype == "float64" or df[i].dtype == "int64":
        df[i].fillna(df[i].median(), inplace=True)
# Out:
# C:\Users\Remo\AppData\Local\Temp\ipykernel_12368\4188211634.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(), inplace=True)
# C:\Users\Remo\AppData\Local\Temp\ipykernel_12368\4188211634.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
df.isnull().sum()
# Out:
# MeetID            0
# Name              0
# Sex               0
# Equipment         0
# Division          0
# BodyweightKg      0
# WeightClassKg     0
# BestSquatKg       0
# BestBenchKg       0
# BestDeadliftKg    0
# TotalKg           0
# Place             0
# Wilks             0
# dtype: int64

# %%
for i in df.columns:
    print(f"{i} : " , df[i].nunique())
# Out:
# MeetID :  8482
# Name :  136687
# Sex :  2
# Equipment :  5
# Division :  4246
# BodyweightKg :  9110
# WeightClassKg :  51
# BestSquatKg :  1507
# BestBenchKg :  1470
# BestDeadliftKg :  1385
# TotalKg :  4340
# Place :  81
# Wilks :  64827

# %%
new_df = df.drop(["Name" , "Equipment" , "Division" , "WeightClassKg" , "Place"] , inplace=False , axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
new_df["Sex"] = le.fit_transform(new_df["Sex"])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 385869 entries, 0 to 386413
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MeetID          385869 non-null  int64
#  1   Sex             385869 non-null  int64
#  2   BodyweightKg    385869 non-null  float64
#  3   BestSquatKg     385869 non-null  float64
#  4   BestBenchKg     385869 non-null  float64
#  5   BestDeadliftKg  385869 non-null  float64
#  6   TotalKg         385869 non-null  float64
#  7   Wilks           385869 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 26.5 MB

# %%
from sklearn.model_selection import train_test_split 

x = new_df.drop(["Sex"] , axis=1 , inplace=False)
y = new_df["Sex"]

# %%
x.head()
# Out:
#    MeetID  BodyweightKg  BestSquatKg  BestBenchKg  BestDeadliftKg  TotalKg  \
# 0       0         59.60        47.63        20.41           70.31   138.35
# 1       0         58.51       142.88        95.25          163.29   401.42
# 2       0         58.51       142.88        95.25          163.29   401.42
# 3       0         58.51       174.63        95.25          195.00    95.25
# 4       0         63.68       174.63        31.75           90.72   122.47
#
#     Wilks
# 0  155.05
# 1  456.38
# 2  456.38
# 3  108.29
# 4  130.47

# %%
y.sample(5)
# Out:
# 347782    1
# 59744     0
# 24000     1
# 256868    0
# 283571    0
# Name: Sex, dtype: int64

# %%
x_train, x_test ,  y_train , y_test = train_test_split(x ,y , test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.99495944229922

# %%
df.to_csv("OpenPowerOutput.csv" , index=False)
