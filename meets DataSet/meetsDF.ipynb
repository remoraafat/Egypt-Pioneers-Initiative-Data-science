# %%
import pandas as pd

# %%
df = pd.read_csv("meets.csv")

# %%
df.head(10)
# Out:
#    MeetID        MeetPath Federation        Date MeetCountry MeetState  \
# 0       0  365strong/1601  365Strong  2016-10-29         USA        NC
# 1       1  365strong/1602  365Strong  2016-11-19         USA        MO
# 2       2  365strong/1603  365Strong  2016-07-09         USA        NC
# 3       3  365strong/1604  365Strong  2016-06-11         USA        SC
# 4       4  365strong/1605  365Strong  2016-04-10         USA        SC
# 5       5  365strong/1701  365Strong  2017-04-22         USA        NC
# 6       6  365strong/1702  365Strong  2017-01-21         USA        GA
# 7       7  365strong/1703  365Strong  2017-06-10         USA        MO
# 8       8  365strong/1704  365Strong  2017-07-15         USA        SC
# 9       9  365strong/1705  365Strong  2017-08-12         USA        NC
#
#        MeetTown                                           MeetName
# 0     Charlotte  2016 Junior & Senior National Powerlifting Cha...
# ...

# %%
df.describe()
# Out:
#             MeetID
# count  8482.000000
# mean   4240.500000
# std    2448.686825
# min       0.000000
# 25%    2120.250000
# 50%    4240.500000
# 75%    6360.750000
# max    8481.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8482 entries, 0 to 8481
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MeetID       8482 non-null   int64
#  1   MeetPath     8482 non-null   object
#  2   Federation   8482 non-null   object
#  3   Date         8482 non-null   object
#  4   MeetCountry  8482 non-null   object
#  5   MeetState    5496 non-null   object
#  6   MeetTown     6973 non-null   object
#  7   MeetName     8482 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 530.3+ KB

# %%
df.describe(include="object")
# Out:
#                MeetPath Federation        Date MeetCountry MeetState  \
# count              8482       8482        8482        8482      5496
# unique             8482         60        2652          45        80
# top     xpc/2017-finals        NSF  2017-02-18         USA        TX
# freq                  1       2517          56        3894       872
#
#           MeetTown     MeetName
# count         6973         8482
# unique        1539         5217
# top     Brumunddal  Klubbstevne
# freq           163          584

# %%
df.describe(include="int64")
# Out:
#             MeetID
# count  8482.000000
# mean   4240.500000
# std    2448.686825
# min       0.000000
# 25%    2120.250000
# 50%    4240.500000
# 75%    6360.750000
# max    8481.000000

# %%
df.sample(5)
# Out:
#       MeetID          MeetPath Federation        Date MeetCountry MeetState  \
# 7924    7924         uspa/0516       USPA  2015-10-31         USA        VA
# 3042    3042          nsf/2787        NSF  2014-08-16      Norway       NaN
# 6614    6614  usapl/CO-2016-03      USAPL  2016-09-25         USA        CO
# 22        22          apa/1001        APA  2010-11-13         USA        FL
# 4764    4764           pa/1662         PA  2016-11-19   Australia       NSW
#
#          MeetTown                                     MeetName
# 7924       Vinton                                 Monster Bash
# 3042        Gruva                                  Klubbstevne
# 6614  Wheat Ridge                           Colorado Fall Open
# 22            NaN                           Ironfest Challenge
# 4764       Sydney  2016 Matti Tikka Powerlifting Championships

# %%
df.loc[0:5 , ["MeetPath", "Date"]]
# Out:
#          MeetPath        Date
# 0  365strong/1601  2016-10-29
# 1  365strong/1602  2016-11-19
# 2  365strong/1603  2016-07-09
# 3  365strong/1604  2016-06-11
# 4  365strong/1605  2016-04-10
# 5  365strong/1701  2017-04-22

# %%
df.value_counts()
# Out:
# MeetID  MeetPath         Federation  Date        MeetCountry  MeetState  MeetTown       MeetName
# 8481    xpc/2017-finals  XPC         2017-03-03  USA          OH         Columbus       2017 XPC Finals                      1
# 8464    wrpf-aus/1701    WRPF-AUS    2017-09-02  Australia    TAS        Launceston     Down Under Classic                   1
# 8458    wrpf/1709        WRPF        2017-08-26  USA          CA         Mountain View  Boss of Bosses 4 Invitational        1
# 8457    wrpf/1708        WRPF        2017-08-25  USA          CA         Mountain View  Boss of Bosses 4 Open                1
# 8450    wrpf/1606        WRPF        2016-08-20  USA          CA         Mountain View  Boss of Bosses 3 Invitational        1
#                                                                                                                             ..
# ...

# %%
df.count()
# Out:
# MeetID         8482
# MeetPath       8482
# Federation     8482
# Date           8482
# MeetCountry    8482
# MeetState      5496
# MeetTown       6973
# MeetName       8482
# dtype: int64

# %%
df.isnull().sum()
# Out:
# MeetID            0
# MeetPath          0
# Federation        0
# Date              0
# MeetCountry       0
# MeetState      2986
# MeetTown       1509
# MeetName          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
new_df= df.drop(["MeetState","MeetTown"] , axis=1 , inplace=False)

# %%
new_df.isnull().sum()
# Out:
# MeetID         0
# MeetPath       0
# Federation     0
# Date           0
# MeetCountry    0
# MeetName       0
# dtype: int64

# %%
new_df.count()
# Out:
# MeetID         8482
# MeetPath       8482
# Federation     8482
# Date           8482
# MeetCountry    8482
# MeetName       8482
# dtype: int64

# %%
new_df.head(10)
# Out:
#    MeetID        MeetPath Federation        Date MeetCountry  \
# 0       0  365strong/1601  365Strong  2016-10-29         USA
# 1       1  365strong/1602  365Strong  2016-11-19         USA
# 2       2  365strong/1603  365Strong  2016-07-09         USA
# 3       3  365strong/1604  365Strong  2016-06-11         USA
# 4       4  365strong/1605  365Strong  2016-04-10         USA
# 5       5  365strong/1701  365Strong  2017-04-22         USA
# 6       6  365strong/1702  365Strong  2017-01-21         USA
# 7       7  365strong/1703  365Strong  2017-06-10         USA
# 8       8  365strong/1704  365Strong  2017-07-15         USA
# 9       9  365strong/1705  365Strong  2017-08-12         USA
#
#                                             MeetName
# 0  2016 Junior & Senior National Powerlifting Cha...
# 1                  Thanksgiving Powerlifting Classic
# 2                             Charlotte Europa Games
# 3                   Carolina Cup Push Pull Challenge
# ...

# %%
df["MeetState"].fillna(df["MeetState"].mode()[0],inplace=True)
# Out:
# C:\Users\Remo\AppData\Local\Temp\ipykernel_12704\603911574.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["MeetState"].fillna(df["MeetState"].mode()[0],inplace=True)

# %%
df["MeetTown"].fillna(df["MeetTown"].mode()[0],inplace=True)
# Out:
# C:\Users\Remo\AppData\Local\Temp\ipykernel_12704\814261768.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["MeetTown"].fillna(df["MeetTown"].mode()[0],inplace=True)

# %%
df.head(10)
# Out:
#    MeetID        MeetPath Federation        Date MeetCountry MeetState  \
# 0       0  365strong/1601  365Strong  2016-10-29         USA        NC
# 1       1  365strong/1602  365Strong  2016-11-19         USA        MO
# 2       2  365strong/1603  365Strong  2016-07-09         USA        NC
# 3       3  365strong/1604  365Strong  2016-06-11         USA        SC
# 4       4  365strong/1605  365Strong  2016-04-10         USA        SC
# 5       5  365strong/1701  365Strong  2017-04-22         USA        NC
# 6       6  365strong/1702  365Strong  2017-01-21         USA        GA
# 7       7  365strong/1703  365Strong  2017-06-10         USA        MO
# 8       8  365strong/1704  365Strong  2017-07-15         USA        SC
# 9       9  365strong/1705  365Strong  2017-08-12         USA        NC
#
#        MeetTown                                           MeetName
# 0     Charlotte  2016 Junior & Senior National Powerlifting Cha...
# ...

# %%
df.isnull().sum()
# Out:
# MeetID         0
# MeetPath       0
# Federation     0
# Date           0
# MeetCountry    0
# MeetState      0
# MeetTown       0
# MeetName       0
# dtype: int64

# %%
for i in df.columns:
    print(f"{i} : " , df[i].unique())
# Out:
# MeetID :  [   0    1    2 ... 8479 8480 8481]
# MeetPath :  ['365strong/1601' '365strong/1602' '365strong/1603' ...
#  'xpc/2016-elite-finals' 'xpc/2016-pro-finals' 'xpc/2017-finals']
# Federation :  ['365Strong' 'AAU' 'ADFPA' 'APA' 'APC' 'APF' 'WPC' 'AAPF' 'CAPO' 'AsianPF'
#  'BB' 'BP' 'BPU' 'CommonwealthPF' 'CPF' 'CPL' 'CPU' 'EPA' 'EPF' 'FESUPO'
#  'FFForce' 'FPO' 'GPA' 'GPC' 'GPC-AUS' 'GPC-GB' 'HERC' 'IPA' 'IPF'
#  'IrishPF' 'MHP' 'MM' 'NAPF' 'NASA' 'NIPF' 'NPA' 'NSF' 'NZPF' 'OceaniaPF'
#  'PA' 'ProRaw' 'RAW' 'RPS' 'XPC' 'RUPC' 'ScottishPL' 'SCT' 'SPF' 'THSPA'
#  'UPA' 'USAPL' 'USPF' 'USPA' 'IPL' 'WelshPA' 'WNPF' 'WRPF' 'WRPF-AUS'
#  'WRPF-CAN' 'WUAP']
# Date :  ['2016-10-29' '2016-11-19' '2016-07-09' ... '2012-03-04' '2014-03-03'
#  '2014-10-06']
# MeetCountry :  ['USA' 'Australia' 'Finland' 'Ireland' 'Indonesia' 'Russia' 'UK' 'England'
#  'New Zealand' 'India' 'Canada' 'Italy' 'Czechia' 'Germany' 'Estonia'
# ...

# %%
for i in df.columns:
    print(f"{i} : " , df[i].nunique())
# Out:
# MeetID :  8482
# MeetPath :  8482
# Federation :  60
# Date :  2652
# MeetCountry :  45
# MeetState :  80
# MeetTown :  1539
# MeetName :  5217

# %%
for i in df.columns:
    print(f"{i} : " , df[i].value_counts())
# Out:
# MeetID :  MeetID
# 8481    1
# 0       1
# 8465    1
# 8464    1
# 8463    1
#        ..
# 6       1
# 5       1
# 4       1
# 3       1
# 2       1
# Name: count, Length: 8482, dtype: int64
# MeetPath :  MeetPath
# xpc/2017-finals    1
# 365strong/1601     1
# wrpf-can/1701      1
# wrpf-aus/1701      1
# wrpf/1714          1
#                   ..
# 365strong/1702     1
# 365strong/1701     1
# 365strong/1605     1
# 365strong/1604     1
# 365strong/1603     1
# Name: count, Length: 8482, dtype: int64
# Federation :  Federation
# NSF               2517
# USAPL              976
# CPU                969
# USPA               864
# THSPA              670
# PA                 493
# SPF                480
# RPS                334
# NZPF               179
# NASA               103
# USPF                91
# IPA                 88
# UPA                 84
# IPF                 78
# CPF                 58
# APF                 53
# NIPF                36
# APA                 33
# ...

# %%
df.to_csv("meetsOutput_1.csv" , index=False)
new_df.to_csv("meetsOutput_2.csv")
